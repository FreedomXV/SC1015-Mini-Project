# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
demodata = pd.read_csv('county_megaset.csv')
demodata.head()
# Out:
#    COUNTYNS  Geographic Identifier - FIPS Code  Area of Land (square meters)  \
# 0    161526                               1001                  1.539602e+09
# 1    161527                               1003                  4.117547e+09
# 2    161528                               1005                  2.292145e+09
# 3    161529                               1007                  1.612167e+09
# 4    161530                               1009                  1.670104e+09
#
#    Area of Water (square meters)            Name    State  \
# 0                       25706961  Autauga County  Alabama
# 1                     1133055836  Baldwin County  Alabama
# 2                       50538698  Barbour County  Alabama
# 3                        9602089     Bibb County  Alabama
# 4                       15015423   Blount County  Alabama
#
#    Average Household Size  Average Household Size - Margin of Error  \
# 0                    2.59                                      0.05
# ...

# %%
print("Data type : ", type(demodata))
print("Data dims : ", demodata.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (3220, 313)

# %%
poverty = pd.DataFrame(demodata[["Percentage of people whose income in the past 12 months is below the poverty level","Confirmed","Deaths"]])

# %%
poverty.describe()
# Out:
#        Percentage of people whose income in the past 12 months is below the poverty level  \
# count                                        3220.000000
# mean                                           15.893385
# std                                             8.087809
# min                                             2.400000
# 25%                                            10.700000
# 50%                                            14.400000
# 75%                                            18.800000
# max                                            64.500000
#
#            Confirmed       Deaths
# count    3220.000000   3220.00000
# mean     1316.137578     45.27764
# std      6962.304363    456.31641
# min         0.000000      0.00000
# 25%        43.000000      0.00000
# 50%       158.000000      2.00000
# 75%       585.000000     13.00000
# max    224051.000000  23500.00000

# %%
poverty.head(20)
# Out:
#     Percentage of people whose income in the past 12 months is below the poverty level  \
# 0                                                15.2
# 1                                                10.4
# 2                                                30.7
# 3                                                18.1
# 4                                                13.6
# 5                                                28.9
# 6                                                22.5
# 7                                                17.9
# 8                                                17.3
# 9                                                13.9
# 10                                               19.1
# 11                                               23.3
# 12                                               23.2
# 13                                               17.9
# 14                                               17.3
# 15                                               15.1
# ...

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(20, 20))
sb.heatmap(poverty.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %%
sb.pairplot(data = poverty)

# %%
US_county_condensed = pd.DataFrame(demodata[["Geographic Identifier - FIPS Code","Name","State","Area of Land (square meters)","Area of Water (square meters)",
                                             "Average Household Size","Total Population","Population Density (people per square kilometer)",
                                             "Percent of Population with No Health Insurance Coverage","Households: Receiving Food Stamps/SNAP (%)",
                                             "Households: Income Below Poverty Level (%)","Lat","Long_",
                                             "Percentage of people whose income in the past 12 months is below the poverty level","Confirmed","Deaths"]])

# %%
US_county_condensed.head()
# Out:
#    Geographic Identifier - FIPS Code            Name    State  \
# 0                               1001  Autauga County  Alabama
# 1                               1003  Baldwin County  Alabama
# 2                               1005  Barbour County  Alabama
# 3                               1007     Bibb County  Alabama
# 4                               1009   Blount County  Alabama
#
#    Area of Land (square meters)  Area of Water (square meters)  \
# 0                  1.539602e+09                       25706961
# 1                  4.117547e+09                     1133055836
# 2                  2.292145e+09                       50538698
# 3                  1.612167e+09                        9602089
# 4                  1.670104e+09                       15015423
#
#    Average Household Size  Total Population  \
# 0                    2.59             55200
# 1                    2.61            208107
# 2                    2.49             25782
# ...

# %%
f = plt.figure(figsize=(20, 20))
sb.heatmap(US_county_condensed.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 8}, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %%
US_county_condensed.to_csv("US_county_condensed.csv")
