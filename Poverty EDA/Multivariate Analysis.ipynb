# %% [markdown]
# ### Importing essential libraries and the dataset

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
covid = pd.read_csv('US_county_condensed(2).csv')
covid.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Geographic Identifier - FIPS Code  \
# 0           0             0                               1001
# 1           1             1                               1003
# 2           2             2                               1005
# 3           3             3                               1007
# 4           4             4                               1009
#
#              Name    State  Area of Land (square meters)  \
# 0  Autauga County  Alabama                  1.539602e+09
# 1  Baldwin County  Alabama                  4.117547e+09
# 2  Barbour County  Alabama                  2.292145e+09
# 3     Bibb County  Alabama                  1.612167e+09
# 4   Blount County  Alabama                  1.670104e+09
#
#    Area of Water (square meters)  Average Household Size  Total Population  \
# 0                       25706961                    2.59             55200
# 1                     1133055836                    2.61            208107
# 2                       50538698                    2.49             25782
# 3                        9602089                    2.99             22527
# 4                       15015423                    2.77             57645
#
#    Population Density (people per square kilometer)  ...  \
# 0                                         35.853419  ...
# 1                                         50.541504  ...
# 2                                         11.247981  ...
# 3                                         13.973114  ...
# 4                                         34.515816  ...
#
#    Households: Receiving Food Stamps/SNAP (%)  \
# 0                                        12.8
# 1                                         7.7
# 2                                        26.8
# 3                                        16.2
# 4                                         9.5
#
#    Households: Income Below Poverty Level (%)        Lat      Long_  \
# 0                                        14.7  32.539527 -86.644082
# 1                                        10.5  30.727750 -87.722071
# 2                                        27.5  31.868263 -85.387129
# 3                                        18.4  32.996421 -87.125115
# 4                                        14.2  33.982109 -86.567906
#
#    Percentage of people whose income in the past 12 months is below the poverty level  \
# 0                                               15.2
# 1                                               10.4
# 2                                               30.7
# 3                                               18.1
# 4                                               13.6
#
#    Confirmed  Deaths  Case density (Per 100000)  Death density (Per 100000)  \
# 0        932      20                1688.405797                   36.231884
# 1       2727      17                1310.383601                    8.168875
# 2        529       4                2051.819099                   15.514700
# 3        327       2                1451.591424                    8.878235
# 4        601       1                1042.588256                    1.734756
#
#    Death Rate (%)
# 0        2.145923
# 1        0.623396
# 2        0.756144
# 3        0.611621
# 4        0.166389
#
# [5 rows x 21 columns]

# %%
covid.columns = ['0','1','FIPS_Code', 'Name', 'State', 'ALand','AWater','HseSize','Pop','PopDensity',
                 'NoHealthInsurance','FoodStamps','Poverty','Lat','Long','IncomePoverty','Cases','Death',
                'CDensity','DDensity','DRate']

# %%
covid.head()
# Out:
#    0  1  FIPS_Code            Name    State         ALand      AWater  \
# 0  0  0       1001  Autauga County  Alabama  1.539602e+09    25706961
# 1  1  1       1003  Baldwin County  Alabama  4.117547e+09  1133055836
# 2  2  2       1005  Barbour County  Alabama  2.292145e+09    50538698
# 3  3  3       1007     Bibb County  Alabama  1.612167e+09     9602089
# 4  4  4       1009   Blount County  Alabama  1.670104e+09    15015423
#
#    HseSize     Pop  PopDensity  ...  FoodStamps  Poverty        Lat  \
# 0     2.59   55200   35.853419  ...        12.8     14.7  32.539527
# 1     2.61  208107   50.541504  ...         7.7     10.5  30.727750
# 2     2.49   25782   11.247981  ...        26.8     27.5  31.868263
# 3     2.99   22527   13.973114  ...        16.2     18.4  32.996421
# 4     2.77   57645   34.515816  ...         9.5     14.2  33.982109
#
#         Long  IncomePoverty  Cases  Death     CDensity   DDensity     DRate
# 0 -86.644082           15.2    932     20  1688.405797  36.231884  2.145923
# 1 -87.722071           10.4   2727     17  1310.383601   8.168875  0.623396
# 2 -85.387129           30.7    529      4  2051.819099  15.514700  0.756144
# 3 -87.125115           18.1    327      2  1451.591424   8.878235  0.611621
# 4 -86.567906           13.6    601      1  1042.588256   1.734756  0.166389
#
# [5 rows x 21 columns]

# %%
covid.drop(['0','1'], axis=1)
# Out:
#       FIPS_Code                 Name        State         ALand      AWater  \
# 0          1001       Autauga County      Alabama  1.539602e+09    25706961
# 1          1003       Baldwin County      Alabama  4.117547e+09  1133055836
# 2          1005       Barbour County      Alabama  2.292145e+09    50538698
# 3          1007          Bibb County      Alabama  1.612167e+09     9602089
# 4          1009        Blount County      Alabama  1.670104e+09    15015423
# ...         ...                  ...          ...           ...         ...
# 3215      72145  Vega Baja Municipio  Puerto Rico  1.187776e+08    57795019
# 3216      72147    Vieques Municipio  Puerto Rico  1.315414e+08   552192819
# 3217      72149   Villalba Municipio  Puerto Rico  9.229857e+07     3622639
# 3218      72151    Yabucoa Municipio  Puerto Rico  1.430052e+08    72592521
# 3219      72153      Yauco Municipio  Puerto Rico  1.753719e+08     1625259
#
#       HseSize     Pop  PopDensity  NoHealthInsurance  FoodStamps  Poverty  \
# 0        2.59   55200   35.853419                7.1        12.8     14.7
# 1        2.61  208107   50.541504                8.9         7.7     10.5
# 2        2.49   25782   11.247981               11.3        26.8     27.5
# 3        2.99   22527   13.973114               10.7        16.2     18.4
# 4        2.77   57645   34.515816               10.8         9.5     14.2
# ...       ...     ...         ...                ...         ...      ...
# 3215     2.93   53371  449.335380                9.5        38.1     45.8
# 3216     3.55    8771   66.678630               12.0        42.2     48.8
# 3217     2.96   22993  249.115455                3.8        53.6     48.3
# 3218     2.91   34149  238.795547                5.0        53.2     53.3
# 3219     3.35   36439  207.781273                6.1        50.1     54.0
#
#             Lat       Long  IncomePoverty  Cases  Death     CDensity  \
# 0     32.539527 -86.644082           15.2    932     20  1688.405797
# 1     30.727750 -87.722071           10.4   2727     17  1310.383601
# 2     31.868263 -85.387129           30.7    529      4  2051.819099
# 3     32.996421 -87.125115           18.1    327      2  1451.591424
# 4     33.982109 -86.567906           13.6    601      1  1042.588256
# ...         ...        ...            ...    ...    ...          ...
# 3215  18.428262 -66.397924           45.2    263      0   492.776976
# 3216  18.123276 -65.440971           45.9     33      0   376.239881
# 3217  18.127951 -66.473115           47.8     70      0   304.440482
# 3218  18.070399 -65.896289           53.1     81      0   237.195818
# 3219  18.080374 -66.858814           49.0    182      0   499.464859
#
#        DDensity     DRate
# 0     36.231884  2.145923
# 1      8.168875  0.623396
# 2     15.514700  0.756144
# 3      8.878235  0.611621
# 4      1.734756  0.166389
# ...         ...       ...
# 3215   0.000000  0.000000
# 3216   0.000000  0.000000
# 3217   0.000000  0.000000
# 3218   0.000000  0.000000
# 3219   0.000000  0.000000
#
# [3220 rows x 19 columns]

# %% [markdown]
# ### Multivariate Linear Regression

# %%
# Extract Response and Predictors
y = pd.DataFrame(covid["CDensity"])
X = pd.DataFrame(covid[['HseSize','PopDensity','NoHealthInsurance','Poverty']])

# %%
# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (2415, 1) (2415, 4)
# Test Set  : (805, 1) (805, 4)

# %%
# Summary Statistics for Response
y_train.describe()
# Out:
#            CDensity
# count   2415.000000
# mean     882.955947
# std     1009.563733
# min        0.000000
# 25%      275.461082
# 50%      566.650162
# 75%     1166.720515
# max    16306.278070

# %%
# Summary Statistics for Predictors
X_train.describe()
# Out:
#            HseSize    PopDensity  NoHealthInsurance      Poverty
# count  2415.000000   2415.000000        2415.000000  2415.000000
# mean      2.528679    100.508406           9.584472    15.597598
# std       0.275660    636.655278           5.063765     7.862089
# min       1.340000      0.014362           0.000000     2.300000
# 25%       2.350000      6.616036           5.800000    10.600000
# 50%       2.490000     17.565491           8.600000    13.900000
# 75%       2.650000     51.119502          12.000000    18.400000
# max       4.690000  27819.804800          46.300000    62.300000

# %%
# Draw the distribution of Response
f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = y_train, orient = "h", ax = axes[0])
sb.histplot(data = y_train, ax = axes[1])
sb.violinplot(data = y_train, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
# Draw the distributions of all Predictors
f, axes = plt.subplots(4, 3, figsize=(18, 12))

count = 0
for var in X_train:
    sb.boxplot(data = X_train[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = X_train[var], ax = axes[count,1])
    sb.violinplot(data = X_train[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Correlation between Response and the Predictors
trainDF = pd.concat([y_train, X_train], axis = 1).reindex(y_train.index)

f = plt.figure(figsize=(12, 8))
sb.heatmap(trainDF.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
# Relationship between Response and the Predictors
sb.pairplot(data = trainDF)

# %% [markdown]
# #### Linear Regression using Scikit-Learn

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression


# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [-1018.70988727]
# Coefficients of Regression 	: a =  [[5.52543847e+02 4.54304234e-01 3.43517222e+01 8.30610222e+00]]
#           Predictors  Coefficients
# 0            HseSize    552.543847
# 1         PopDensity      0.454304
# 2  NoHealthInsurance     34.351722
# 3            Poverty      8.306102

# %%
# Predict the Total values from Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.1640600024836315
# Mean Squared Error (MSE) 	: 851653.0740153325
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: -0.07628427564458784
# Mean Squared Error (MSE) 	: 870086.3969234065

# %% [markdown]
# #### DecisionTreeRegressor using Scikit-Learn

# %%
from sklearn.tree import DecisionTreeRegressor

# Linear Regression using Train Data
dt = DecisionTreeRegressor(max_leaf_nodes=6)
dt.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", dt.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", dt.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.2229006989059622
# Mean Squared Error (MSE) 	: 791706.3551908158
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.13786014856141715
# Mean Squared Error (MSE) 	: 696968.4254961543

# %% [markdown]
# #### Boosting algorithms

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Linear Regression using Train Data
gbr = GradientBoostingRegressor(max_depth = 3)
gbr.fit(X_train, y_train.values.ravel())

# Predict the Total values from Predictors
y_train_pred = gbr.predict(X_train)
y_test_pred = gbr.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", gbr.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", gbr.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5022635123204113
# Mean Squared Error (MSE) 	: 507092.38825914176
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.18044092966334946
# Mean Squared Error (MSE) 	: 662545.402466318

# %% [markdown]
# #### lightgbm

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\user\anaconda3\lib\site-packages (from lightgbm) (0.24.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: wheel in c:\users\user\anaconda3\lib\site-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.0.1)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm

lgb = lightgbm.LGBMRegressor(max_depth=5)
lgb.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = lgb.predict(X_train)
y_test_pred = lgb.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", lgb.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", lgb.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.48134028064500234
# Mean Squared Error (MSE) 	: 528408.9117269019
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.2579052788863172
# Mean Squared Error (MSE) 	: 599921.9134582097

# %% [markdown]
# #### xgboost

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.5.2-py3-none-win_amd64.whl (106.6 MB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.20.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.6.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xg

xg = xg.XGBRFRegressor(max_depth = 6)
xg.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = xg.predict(X_train)
y_test_pred = xg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.4545698599453045
# Mean Squared Error (MSE) 	: 555682.5332180604
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.30007386653791346
# Mean Squared Error (MSE) 	: 565832.1145794216

# %%
import xgboost as xg

xg = xg.XGBRegressor()
xg.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = xg.predict(X_train)
y_test_pred = xg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.943266124241522
# Mean Squared Error (MSE) 	: 57800.29647351047
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.13682776079078196
# Mean Squared Error (MSE) 	: 697803.0252166064

# %% [markdown]
# ### Attempt without outliers

# %%
# Extract Response and Predictors
covid_clean = pd.DataFrame(covid[['CDensity','HseSize','PopDensity','NoHealthInsurance','Poverty']])

# %%
def removeOutliers(df): 
    temp = pd.DataFrame() 
    for var in df: 
        Q1 = df[var].quantile(0.25) 
        Q3 = df[var].quantile(0.75) 
        IQR = Q3 - Q1 
        temp[var] = df[var][((df[var] > (Q1 - 1.5 * IQR)) & (df[var] < (Q3 + 1.5 * IQR)))] 
    return temp

# %%
covid_clean = removeOutliers(covid_clean)

# %%
covid_clean.isnull().sum()
# Out:
# CDensity               0
# HseSize              114
# PopDensity           441
# NoHealthInsurance     73
# Poverty              124
# dtype: int64

# %%
covid_clean=covid_clean.dropna()

# %%
covid_clean.describe()
# Out:
#           CDensity      HseSize   PopDensity  NoHealthInsurance      Poverty
# count  2430.000000  2430.000000  2430.000000        2430.000000  2430.000000
# mean    659.283184     2.461609    23.257930           9.096132    14.460617
# std     568.570513     0.200642    25.108904           4.129744     5.031074
# min       0.000000     1.920000     0.058884           0.700000     2.300000
# 25%     241.276718     2.330000     5.608010           5.800000    10.800000
# 50%     460.710812     2.450000    14.658648           8.500000    13.800000
# 75%     926.103371     2.580000    30.880414          11.600000    17.600000
# max    2487.562189     3.090000   118.019676          21.100000    29.800000

# %%
# Splitting Response and Predictors
y_clean = pd.DataFrame(covid_clean["CDensity"])
X_clean = pd.DataFrame(covid_clean[['HseSize','PopDensity','NoHealthInsurance','Poverty']])

# %%
# Draw the distribution of Response
f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = y_clean, orient = "h", ax = axes[0])
sb.histplot(data = y_clean, ax = axes[1])
sb.violinplot(data = y_clean, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
# Draw the distributions of all Predictors
f, axes = plt.subplots(4, 3, figsize=(18, 12))

count = 0
for var in X_clean:
    sb.boxplot(data = X_clean[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = X_clean[var], ax = axes[count,1])
    sb.violinplot(data = X_clean[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Correlation between Response and the Predictors
trainDF = pd.concat([y_clean, X_clean], axis = 1).reindex(y_clean.index)

f = plt.figure(figsize=(12, 8))
sb.heatmap(trainDF.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
# Relationship between Response and the Predictors
sb.pairplot(data = trainDF)

# %%
# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_clean, y_clean, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train2.shape, X_train2.shape)
print("Test Set  :", y_test2.shape, X_test2.shape)
# Out:
# Train Set : (1822, 1) (1822, 4)
# Test Set  : (608, 1) (608, 4)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression


# Linear Regression using Train Data
linreg2 = LinearRegression()         # create the linear regression object
linreg2.fit(X_train2, y_train2)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg2.intercept_)
print('Coefficients of Regression \t: a = ', linreg2.coef_)
print()

# Print the Coefficients against Predictors
pd.DataFrame(list(zip(X_train2.columns, linreg2.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [-1546.97335876]
# Coefficients of Regression 	: a =  [[603.17684205   4.59807696  21.488071    28.87289657]]
#           Predictors  Coefficients
# 0            HseSize    603.176842
# 1         PopDensity      4.598077
# 2  NoHealthInsurance     21.488071
# 3            Poverty     28.872897

# %%
# Predict the Total values from Predictors
y_train_pred2 = linreg2.predict(X_train2)
y_test_pred2 = linreg2.predict(X_test2)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train2, y_train_pred2, color = "blue")
axes[0].plot(y_train2, y_train2, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test2, y_test_pred2, color = "green")
axes[1].plot(y_test2, y_test2, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg2.score(X_train2, y_train2))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train2, y_train_pred2))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg2.score(X_test2, y_test2))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test2, y_test_pred2))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.24213807299662415
# Mean Squared Error (MSE) 	: 240762.93952188047
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.1725705456531108
# Mean Squared Error (MSE) 	: 280536.7285585494

# %%
# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X_clean, y_clean, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (1822, 1) (1822, 4)
# Test Set  : (608, 1) (608, 4)

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# Linear Regression using Train Data
dt = DecisionTreeRegressor(max_leaf_nodes=6)
dt.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", dt.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", dt.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.2480435962671954
# Mean Squared Error (MSE) 	: 237627.97821652293
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.2515164225177432
# Mean Squared Error (MSE) 	: 257086.84051731435

# %% [markdown]
# #### Gradient boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Linear Regression using Train Data
gbr = GradientBoostingRegressor(max_depth = 2)
gbr.fit(X_train, y_train.values.ravel())

# Predict the Total values from Predictors
y_train_pred = gbr.predict(X_train)
y_test_pred = gbr.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", gbr.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", gbr.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.38136228329363975
# Mean Squared Error (MSE) 	: 195497.54366032968
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.31012987080588716
# Mean Squared Error (MSE) 	: 236954.47330771966

# %% [markdown]
# #### Lightgbm

# %%
lgb = lightgbm.LGBMRegressor(max_depth=2)
lgb.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = lgb.predict(X_train)
y_test_pred = lgb.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", lgb.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", lgb.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.3647817760130755
# Mean Squared Error (MSE) 	: 200737.19904902804
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.3168248531571092
# Mean Squared Error (MSE) 	: 234654.90133075716

# %% [markdown]
# #### xgboost

# %%
import xgboost as xg
xg = xg.XGBRFRegressor(max_depth = 6)
xg.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = xg.predict(X_train)
y_test_pred = xg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.484589789512064
# Mean Squared Error (MSE) 	: 162876.31259261217
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.30575340645859195
# Mean Squared Error (MSE) 	: 238457.68784111997

# %%
import xgboost as xg

xg = xg.XGBRegressor()
xg.fit(X_train, y_train)

# Predict the Total values from Predictors
y_train_pred = xg.predict(X_train)
y_test_pred = xg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", xg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.9444060448091915
# Mean Squared Error (MSE) 	: 17568.411024192796
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.15190875532160797
# Mean Squared Error (MSE) 	: 291299.77613962145
